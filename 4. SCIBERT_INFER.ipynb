# %%
from google.colab import drive
drive.mount('/content/drive')

# %cd /content/drive/MyDrive/bert
# Out:
# Mounted at /content/drive
# /content/drive/MyDrive/NER

# %%
# !pip install -q simpletransformers
# Out:
#      |████████████████████████████████| 6.6 MB 7.9 MB/s
#      |████████████████████████████████| 1.8 MB 42.4 MB/s
#      |████████████████████████████████| 9.1 MB 38.1 MB/s
#      |████████████████████████████████| 362 kB 57.0 MB/s
#      |████████████████████████████████| 1.2 MB 42.7 MB/s
#      |████████████████████████████████| 4.4 MB 40.7 MB/s
#      |████████████████████████████████| 101 kB 11.4 MB/s
#      |████████████████████████████████| 596 kB 36.6 MB/s
#      |████████████████████████████████| 147 kB 39.5 MB/s
#      |████████████████████████████████| 181 kB 50.4 MB/s
#      |████████████████████████████████| 63 kB 1.9 MB/s
#      |████████████████████████████████| 212 kB 37.3 MB/s
#      |████████████████████████████████| 140 kB 52.6 MB/s
#      |████████████████████████████████| 1.1 MB 45.0 MB/s
#      |████████████████████████████████| 127 kB 47.7 MB/s
#      |████████████████████████████████| 271 kB 58.4 MB/s
#      |████████████████████████████████| 144 kB 54.0 MB/s
# ...

# %%
from simpletransformers.ner import NERModel
import pandas as pd

# %%
data = pd.read_excel("ScopusJoournalsAll.xlsx")
abstracts = data["Abstract"].tolist()
data.head()
# Out:
#                                              Authors  \
# 0  Korkeamäki L., Sjödin D., Kohtamäki M., Parida V.
# 1              Raddats C., Naik P., Ziaee Bigdeli A.
# 2                        Kim C., Ishii R., Park J.Y.
# 3                 Zhang M., Liu H., Chen M., Tang X.
# 4                 Randhawa K., Wilden R., Akaka M.A.
#
#                                        Author(s) ID  \
# 0  57219092396;36136176000;14219258300;14065252500;
# 1              35800399300;57215967784;56928424400;
# 2              56156300600;57607987500;24330041500;
# 3  57223440793;24528829100;57194242525;12763890000;
# 4              55523208900;24072600100;24337484000;
#
#                                                Title    Year  \
# 0  Coping with the relational paradoxes of outcom...  2022.0
# 1  Creating value in servitization through digita...  2022.0
# 2  Does brand equity matter in small retailers' h...  2022.0
# 3  Managerial ties: How much do they matter for o...  2022.0
# ...

# %%
model = NERModel( 'bert', '/content/drive/MyDrive/bert/outputs')
predictions, _ = model.predict(abstracts)
# Out:
# ...
# Running Prediction:   0%|          | 0/6585 [00:00<?, ?it/s]

# %%
import pickle
with open('predictions.pkl', 'wb') as f:
   pickle.dump(predictions, f)
